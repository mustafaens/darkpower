# %%
from __future__ import print_function, division

import nsfg

# %%
pres = nsfg.ReadFemPreg()

# %%
pres.head(20)
# Out:
#     caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0        1         1        NaN        NaN       NaN       NaN       6.0
# 1        1         2        NaN        NaN       NaN       NaN       6.0
# 2        2         1        NaN        NaN       NaN       NaN       5.0
# 3        2         2        NaN        NaN       NaN       NaN       6.0
# 4        2         3        NaN        NaN       NaN       NaN       6.0
# 5        6         1        NaN        NaN       NaN       NaN       6.0
# 6        6         2        NaN        NaN       NaN       NaN       6.0
# 7        6         3        NaN        NaN       NaN       NaN       6.0
# 8        7         1        NaN        NaN       NaN       NaN       5.0
# 9        7         2        NaN        NaN       NaN       NaN       5.0
# 10      12         1        NaN        NaN       NaN       NaN       5.0
# 11      14         1        NaN        NaN       NaN       NaN       6.0
# ...

# %%
pres.tail(30)
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 13563   12547         2        NaN        NaN       NaN       NaN       6.0
# 13564   12547         3        NaN        NaN       NaN       NaN       6.0
# 13565   12550         1        NaN        NaN       NaN       NaN       6.0
# 13566   12551         1        NaN        NaN       NaN       NaN       5.0
# 13567   12554         1        NaN        NaN       NaN       NaN       3.0
# 13568   12554         2        NaN        NaN       NaN       NaN       4.0
# 13569   12556         1        NaN        NaN       NaN       NaN       6.0
# 13570   12556         2        NaN        NaN       NaN       NaN       6.0
# 13571   12556         3        NaN        NaN       NaN       NaN       6.0
# 13572   12556         4        NaN        NaN       NaN       NaN       6.0
# 13573   12561         1        NaN        NaN       NaN       NaN       6.0
# ...

# %%
len(pres.columns)
# Out:
# 244

# %%
len(pres)
# Out:
# 13593

# %%
print ("there are " + str(len(pres)) + " rows and "+ str(len(pres.columns))+ " columns")
# Out:
# there are 13593 rows and 244 columns

# %%
pres['agescrn'].value_counts()
# Out:
# 36    740
# 37    695
# 40    679
# 32    665
# 38    657
# 43    650
# 33    640
# 35    638
# 41    636
# 34    636
# 31    618
# 42    594
# 44    589
# 29    586
# 30    577
# 39    575
# 27    502
# 28    493
# 26    453
# 25    416
# 24    359
# 23    345
# 22    277
# 21    187
# 20    140
# 19    111
# 18     76
# 17     36
# 16     16
# 15      7
# Name: agescrn, dtype: int64

# %%
print (pres.agescrn.min())
print(pres.agescrn.max())
# Out:
# 15
# 44

# %%
pres['pregnum'][pres.agescrn<=25]
# Out:
# 2        3
# 3        3
# 4        3
# 41       1
# 60       1
# 65       1
# 66       2
# 67       2
# 77       1
# 78       3
# 79       3
# 80       3
# 93       2
# 94       2
# 100      1
# 114      1
# 130      3
# 131      3
# 132      3
# 133      6
# 134      6
# 135      6
# 136      6
# 137      6
# 138      6
# 139      1
# 160      1
# 163      2
# 164      2
# 167      1
#         ..
# 13279    5
# 13280    5
# 13292    2
# 13293    2
# 13313    1
# 13314    1
# 13340    1
# 13365    3
# 13366    3
# 13367    3
# 13393    2
# 13394    2
# 13408    1
# 13414    1
# 13424    2
# 13425    2
# 13438    3
# 13439    3
# 13440    3
# 13460    4
# 13461    4
# 13462    4
# 13463    4
# 13473    1
# 13479    2
# 13480    2
# 13495    1
# 13532    2
# 13533    2
# 13565    1
# Name: pregnum, dtype: int64

# %%
pres['pregnum'][pres.agescrn.max()]
# Out:
# 4
